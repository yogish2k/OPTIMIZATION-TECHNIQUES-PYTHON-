# %% [markdown]
# ## 2 Variables

# %%
import math as mp

## Initial Points
x = float(input("Enter the x coordinate of initital point:"))
y = float(input("Enter the y coordinate of initital point:"))

## Delta Points
Delta_x = float(input("Enter the x coordinate of delta value"))
Delta_y = float(input("Enter the y coordinate of delta value"))

#Epsilon Value
eps = float(input("enter epislon value"))

## ENTER THE FUNCTION HERE
def f(x,y):
    return (x**2+x1-11)**2 + (x+x1**2-7)**2 ### Enter the function.

xb = x0 = [x,y]

z=(mp.sqrt((Delta_x/2)**2+(Delta_y/2)**2))

if ((mp.sqrt((Delta_x/2)**2+(Delta_y/2)**2))<eps):
    print(z,"is less than epsilon")

while((mp.sqrt((Delta_x/2)**2+(Delta_y/2)**2))>eps):
    Coll = []
    Coll.append(f(x,y))
    Coll.append(f(x-(Delta_x/2),y+(Delta_y/2)))
    Coll.append(f(x+(Delta_x/2),y+(Delta_y/2)))
    Coll.append(f(x-(Delta_x/2),y-(Delta_y/2)))
    Coll.append(f(x+(Delta_x/2),y-(Delta_y/2)))
    print("Minimum Value is",min(Coll))
    pos = Coll.index(min(Coll))
    if pos == 0:
        x = x
        y = y
    elif pos == 1:
        x = x-(Delta_x/2)
        y = y+(Delta_y/2)
    elif pos == 2:
        x = x+(Delta_x/2)
        y = y+(Delta_y/2)
    elif pos == 3:
        x = x-(Delta_x/2)
        y = y-(Delta_y/2)
    else:
        x = x+(Delta_x/2)
        y = y-(Delta_y/2)
    xb = [x,y]
    if xb == x0:
        Delta_x = Delta_x/2
        Delta_y = Delta_y/2
    else:
        x0 = xb
    print("Minimum is at (",x,",",y,")")
# Out:
# Enter the x coordinate of initital point:0
# Enter the y coordinate of initital point:0
# Enter the x coordinate of delta value0.1
# Enter the y coordinate of delta value0.1
# enter epislon value0.5
# 0.07071067811865477 is less than epsilon

# %% [markdown]
# ## Number of iterations Case

# %%
import math as mp
x = float(input("Enter the x coordinate of initital point:"))
y = float(input("Enter the y coordinate of initital point:"))
Delta_x = float(input("Enter the x coordinate of delta value"))
Delta_y = float(input("Enter the y coordinate of delta value"))
#eps = float(input("enter epislon value"))
n = int(input("Give the number of Iterations"))
def f(x,y):
    return ((x**2)-3)**2+((y**2)-2)**2
xb = x0 = [x,y]
count = 0
while(count<n):
    Coll = []
    Coll.append(f(x,y))
    Coll.append(f(x-(Delta_x/2),y+(Delta_y/2)))
    Coll.append(f(x+(Delta_x/2),y+(Delta_y/2)))
    Coll.append(f(x-(Delta_x/2),y-(Delta_y/2)))
    Coll.append(f(x+(Delta_x/2),y-(Delta_y/2)))
    print("Minimum Value is",min(Coll))
    pos = Coll.index(min(Coll))
    
    if pos == 0:
        x = x
        y = y
    elif pos == 1:
        x = x-(Delta_x/2)
        y = y+(Delta_y/2)
    elif pos == 2:
        x = x+(Delta_x/2)
        y = y+(Delta_y/2)
    elif pos == 3:
        x = x-(Delta_x/2)
        y = y-(Delta_y/2)
    else:
        x = x+(Delta_x/2)
        y = y-(Delta_y/2)
    xb = [x,y]
    if xb == x0:
        Delta_x = Delta_x/2
        Delta_y = Delta_y/2
    else:
        x0 = xb
    print("Minimum is at (",x,",",y,")")
    count += 1
# Out:
# Enter the x coordinate of initital point:2
# Enter the y coordinate of initital point:2
# Enter the x coordinate of delta value1
# Enter the y coordinate of delta value1
# Give the number of Iterations3
# Minimum Value is -3.25
# Minimum is at ( 1.5 , 1.5 )
# Minimum Value is -4.0
# Minimum is at ( 2.0 , 1.0 )
# Minimum Value is -4.0
# Minimum is at ( 2.0 , 1.0 )
